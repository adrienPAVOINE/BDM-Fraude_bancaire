# %% [markdown]
# # Import et premier coup d'oeil

# %%
import pandas as pd

# %%
df = pd.read_csv("D:/M2 SISE/FOUILLE DE DONNEES/Projet/dataproject.csv",sep=";",nrows=1000,decimal=",")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ZIBZIN                    1000 non-null   object
#  1   IDAvisAutorisAtionCheque  1000 non-null   int64
#  2   MontAnt                   1000 non-null   float64
#  3   DAteTrAnsAction           1000 non-null   object
#  4   CodeDecision              1000 non-null   int64
#  5   VerifiAnceCPT1            1000 non-null   int64
#  6   VerifiAnceCPT2            1000 non-null   int64
#  7   VerifiAnceCPT3            1000 non-null   int64
#  8   D2CB                      1000 non-null   int64
#  9   ScoringFP1                1000 non-null   float64
#  10  ScoringFP2                1000 non-null   float64
#  11  ScoringFP3                1000 non-null   float64
#  12  TAuxImpNb_RB              1000 non-null   float64
# ...

# %%
df.describe()
# Out:
#        IDAvisAutorisAtionCheque      MontAnt  CodeDecision  VerifiAnceCPT1  \
# count              1.000000e+03  1000.000000   1000.000000     1000.000000
# mean               7.107682e+07    54.635600      0.010000        0.357000
# std                6.361002e+03    58.673596      0.141138        0.491724
# min                7.105153e+07     4.200000      0.000000        0.000000
# 25%                7.107759e+07    24.870000      0.000000        0.000000
# 50%                7.107832e+07    38.570000      0.000000        0.000000
# 75%                7.107901e+07    61.625000      0.000000        1.000000
# max                7.107975e+07   740.000000      2.000000        2.000000
#
#        VerifiAnceCPT2  VerifiAnceCPT3         D2CB   ScoringFP1   ScoringFP2  \
# count     1000.000000      1000.00000  1000.000000  1000.000000  1000.000000
# mean         0.383000         0.44400   307.440000     1.874533     1.802083
# ...

# %%
df.head(5)
# Out:
#                       ZIBZIN  IDAvisAutorisAtionCheque  MontAnt  \
# 0  A034010041908012010710730                  71051532    40.17
# 1  A035010041908006493331734                  71051533    20.00
# 2  A013010003908005150136747                  71051534    35.00
# 3  A013010041908025639221029                  71051536    20.00
# 4  A013010003908005556100283                  71051538    20.00
#
#        DAteTrAnsAction  CodeDecision  VerifiAnceCPT1  VerifiAnceCPT2  \
# 0  2016-03-21 07:47:38             0               1               1
# 1  2016-03-21 08:04:57             0               0               0
# 2  2016-03-21 08:06:45             0               0               0
# 3  2016-03-21 08:11:38             0               0               0
# 4  2016-03-21 08:17:11             0               0               0
#
#    VerifiAnceCPT3  D2CB  ScoringFP1  ...  TAuxImpNB_CPM  EcArtNumCheq  \
# 0               1   535         0.0  ...      21.834061             0
# ...

# %% [markdown]
# # Pré-traitement des données

# %%
#Passer les noms de colonnes en minuscules
df.columns = df.columns.str.lower()
#Conversion de la date de transaction en datetime
df['datetransaction'] = pd.to_datetime(df['datetransaction'])

# %%
#creation des colonnes année,mois,jours
df['year']=df['datetransaction'].dt.year 
df['month']=df['datetransaction'].dt.month
df['day']=df['datetransaction'].dt.day
# Out:
#                         zibzin  idavisautorisationcheque  montant  \
# 0    A034010041908012010710730                  71051532    40.17
# 1    A035010041908006493331734                  71051533    20.00
# 2    A013010003908005150136747                  71051534    35.00
# 3    A013010041908025639221029                  71051536    20.00
# 4    A013010003908005556100283                  71051538    20.00
# ..                         ...                       ...      ...
# 995  A013010041908020868381529                  71079737    63.56
# 996  A065016906908087007586513                  71079740   140.79
# 997  A034010041908008601112230                  71079741    49.01
# 998  A050010004908153900150627                  71079743   102.88
# 999  A072017906908005934664001                  71079748    56.51
#
#         datetransaction  codedecision  verifiancecpt1  verifiancecpt2  \
# 0   2016-03-21 07:47:38             0               1               1
# ...

# %%
import seaborn as sns
sns.set()
#c'est de la merde mdr
sns.lineplot(x=df['datetransaction'], y=df['montant'],data=df)
